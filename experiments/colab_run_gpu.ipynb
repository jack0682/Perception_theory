# %% [markdown]
# # Colab에서 응집도 스케일 검증 실험 (GPU 가속)
#
# GitHub 저장소에서 직접 클론하여 **GPU(CUDA)로 가속** 실행합니다.
# - 저장소: `jack0682/Perception_theory`
# - 실험: `exp_cohesion_scale.py` (병렬 처리 + CuPy CUDA)
# - **⚠️ 필수: 먼저 런타임을 GPU로 설정하세요!**
#   - 메뉴: `런타임` → `런타임 유형 변경` → `GPU` 선택 (T4 또는 A100)

# %% [markdown]
# ## 셀 0️⃣: GPU/CUDA 확인

# %%
# GPU 확인
# !nvidia-smi

import torch
print(f"\n✓ PyTorch CUDA 사용 가능: {torch.cuda.is_available()}")
print(f"  GPU 이름: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
print(f"  CUDA 버전: {torch.version.cuda}")

# CuPy 설치 가능 여부
try:
    import cupy as cp
    print(f"\n✓ CuPy 설치됨 (GPU 배열 지원)")
except ImportError:
    print(f"\n✗ CuPy 미설치 (아래 셀에서 설치됨)")

# %% [markdown]
# ## 셀 1️⃣: 의존성 설치 (GPU 가속 포함)

# %%
# CuPy 설치 (GPU 가속용)
print("CuPy 설치 중... (1-2분 소요)")
# !pip install -q cupy-cuda12x  # Colab의 CUDA 12.x와 호환

# 기타 의존성
# !pip install -q numpy scipy networkx matplotlib torch

print("\n✓ 의존성 설치 완료")

# %% [markdown]
# ## 셀 2️⃣: GitHub 저장소 클론

# %%
# GitHub에서 저장소 클론
import os
import subprocess

repo_url = 'https://github.com/jack0682/Perception_theory.git'
repo_dir = '/content/Perception_theory'

# 이미 클론된 경우 스킵
if not os.path.exists(repo_dir):
    # !git clone {repo_url} {repo_dir}

# 작업 디렉토리 설정
os.chdir(repo_dir)
# %cd {repo_dir}

# 디렉토리 확인
print("\n✓ 저장소 준비 완료")
print(f"현재 디렉토리: {os.getcwd()}")
print(f"\n주요 폴더:")
for item in os.listdir('.'):
    if os.path.isdir(item) and not item.startswith('.'):
        print(f"  - {item}/")

# %% [markdown]
# ## 셀 3️⃣: Python 경로 설정 및 GPU 모드 선택

# %%
import sys
import os
from pathlib import Path

# 프로젝트 루트 동적 설정 (현재 작업 디렉토리 기준)
# Colab: /content/Perception_theory, 로컬: /Users/ojaehong/Perception/Perception_theory
repo_root = Path.cwd()
if not (repo_root / 'scc').exists():
    # experiments 폴더에서 실행된 경우
    repo_root = repo_root.parent

sys.path.insert(0, str(repo_root))

# GPU 모드 선택
use_gpu = True  # True: GPU 가속 (CuPy), False: CPU 모드

print(f"\n실행 모드: {'GPU (CUDA 가속)' if use_gpu else 'CPU'}")
print(f"프로젝트 루트: {repo_root}")

# 모듈 임포트 확인
try:
    from scc.graph import GraphState
    from scc.params import ParameterRegistry
    from scc.optimizer import find_formation
    print("✓ SCC 모듈 임포트 성공")
except ImportError as e:
    print(f"✗ 임포트 실패: {e}")

# CuPy 및 GPU 확인
if use_gpu:
    try:
        import cupy as cp
        import cupyx.scipy.sparse as cuspsp
        print("✓ CuPy/GPU 임포트 성공")
        print(f"  GPU 메모리: {cp.cuda.MemoryPointer.get_device().mempool.get_limit() / 1e9:.1f} GB")
    except ImportError as e:
        print(f"⚠️  CuPy 실패, CPU 모드로 전환: {e}")
        use_gpu = False

# %% [markdown]
# ## 셀 4️⃣: 실험 파라미터 설정

# %%
# 실험 파라미터
max_size = 256          # 최대 격자 크기
c_ref = 0.25            # 부피 분수
n_workers = 2           # 워커 수 (병렬)

# 결과 디렉토리 동적 설정
results_dir = Path('experiments/results')
results_dir.mkdir(parents=True, exist_ok=True)
output_file = str(results_dir / f'cohesion_scale_gpu_c{c_ref:.2f}.json')

# GPU 활용도 최대화 (배치 크기 조정)
batch_mode = use_gpu    # GPU면 배치 모드 활용

print(f"실험 파라미터:")
print(f"  max_size: {max_size}")
print(f"  c_ref: {c_ref}")
print(f"  n_workers: {n_workers}")
print(f"  output: {output_file}")
print(f"  GPU 모드: {use_gpu}")
print(f"  배치 모드: {batch_mode}")
print()

# %% [markdown]
# ## 셀 5️⃣: 실험 실행 (GPU 가속)

# %%
import subprocess
import os

# 환경 변수 설정
env = os.environ.copy()
env['CUDA_VISIBLE_DEVICES'] = '0'  # GPU 0 사용
env['OMP_NUM_THREADS'] = '4'       # CPU 스레드 수
env['MKL_NUM_THREADS'] = '4'       # MKL 스레드 수

# 실험 실행 명령어
cmd = [
    'python3',
    'experiments/exp_cohesion_scale.py',
    '--max-size', str(max_size),
    '--c-ref', str(c_ref),
    '--n-workers', str(n_workers),
    '--output', output_file
]

# GPU 플래그 추가
if use_gpu:
    cmd.append('--gpu')

print(f"실행 명령어: {' '.join(cmd)}")
print(f"GPU 모드: {use_gpu}")
print("="*130)
print()

# GPU 메모리 모니터링
if use_gpu:
    print("GPU 리소스 모니터링 시작...\n")

result = subprocess.run(cmd, capture_output=True, text=True, env=env)

# 출력 표시
if result.stdout:
    print(result.stdout)
if result.stderr:
    print("[STDERR]")
    print(result.stderr)

if result.returncode == 0:
    print("\n✓ 실험 완료")
else:
    print(f"\n✗ 오류 발생 (return code: {result.returncode})")

# %% [markdown]
# ## 셀 6️⃣: GPU 사용량 확인

# %%
# GPU 최종 상태 확인
print("실험 후 GPU 상태:\n")
# !nvidia-smi

# 메모리 사용량
import torch
if torch.cuda.is_available():
    print(f"\nCUDA 메모리 사용량:")
    print(f"  할당: {torch.cuda.memory_allocated(0) / 1e9:.2f} GB")
    print(f"  예약: {torch.cuda.memory_reserved(0) / 1e9:.2f} GB")
    print(f"  캐시: {torch.cuda.memory_cached(0) / 1e9:.2f} GB")

# %% [markdown]
# ## 셀 7️⃣: 결과 로드 및 분석

# %%
import json
import numpy as np

# 결과 로드
with open(output_file) as f:
    results = json.load(f)

print(f"\n{'='*130}")
print("분석")
print(f"{'='*130}\n")

sorted_keys = sorted(results.keys())
bind_vals = [results[k]['bind'] for k in sorted_keys]
sep_vals = [results[k]['sep'] for k in sorted_keys]
time_vals = [results[k]['time_sec'] for k in sorted_keys]

# 테이블
print(f"{'Grid':>10} {'Bind':>10} {'Sep':>10} {'Inside':>10} {'Persist':>10} {'Energy':>12} {'Time(s)':>10} {'Iter':>8}")
print("-"*130)
for k in sorted_keys:
    r = results[k]
    print(f"{k:>10} {r['bind']:>10.4f} {r['sep']:>10.4f} {r['inside']:>10.4f} {r['persist']:>10.4f} "
          f"{r['energy']:>12.6f} {r['time_sec']:>10.1f} {r['n_iter']:>8d}")

# 통계
print(f"\n{'─'*130}")
print("통계:")
print(f"  Bind:  min={min(bind_vals):.4f}, max={max(bind_vals):.4f}, "
      f"mean={np.mean(bind_vals):.4f}, std={np.std(bind_vals):.4f}")
print(f"  Sep:   min={min(sep_vals):.4f}, max={max(sep_vals):.4f}, "
      f"mean={np.mean(sep_vals):.4f}, std={np.std(sep_vals):.4f}")
print(f"  Time:  total={sum(time_vals):.1f}s, mean={np.mean(time_vals):.1f}s/grid")

# 결론
print(f"\n{'─'*130}")
print("결론:")

if min(bind_vals) > 0.5:
    print(f"  ✓ 강한 응집: 모든 격자에서 Bind > 0.5")
elif min(bind_vals) > 0.3:
    print(f"  △ 중간 응집: 모든 격자에서 0.3 < Bind < 0.5")
else:
    print(f"  ✗ 약한 응집: Bind < 0.3")

bind_change = (bind_vals[-1] - bind_vals[0]) / bind_vals[0] * 100 if bind_vals[0] != 0 else 0
if abs(bind_change) < 10:
    print(f"  ✓ 안정적: Bind 변화 {bind_change:+.1f}% (< 10%)")
else:
    print(f"  △ 변동: Bind 변화 {bind_change:+.1f}%")

if all(sep < 0.5 for sep in sep_vals):
    print(f"  ✓ 분리 안정: 모든 격자에서 Sep < 0.5")
else:
    print(f"  △ 분리 증가: 일부 격자에서 Sep > 0.5")

print(f"\n{'='*130}")

# %% [markdown]
# ## 셀 8️⃣: 시각화

# %%
import matplotlib.pyplot as plt

if len(results) >= 2:
    sorted_keys = sorted(results.keys())
    grid_labels = [k.replace('x', '×') for k in sorted_keys]
    
    bind_vals = [results[k]['bind'] for k in sorted_keys]
    sep_vals = [results[k]['sep'] for k in sorted_keys]
    inside_vals = [results[k]['inside'] for k in sorted_keys]
    persist_vals = [results[k]['persist'] for k in sorted_keys]
    energy_vals = [results[k]['energy'] for k in sorted_keys]
    time_vals = [results[k]['time_sec'] for k in sorted_keys]

    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    fig.suptitle(f'응집도 스케일 검증 (c_ref={c_ref}) [GPU 가속]', fontsize=16, fontweight='bold')

    # Bind
    axes[0, 0].plot(grid_labels, bind_vals, 'o-', color='#2E86AB', linewidth=2, markersize=8)
    axes[0, 0].axhline(y=0.5, color='red', linestyle='--', alpha=0.5, label='Threshold=0.5')
    axes[0, 0].set_title('Bind (응집 강도)', fontweight='bold')
    axes[0, 0].set_ylabel('Bind')
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Sep
    axes[0, 1].plot(grid_labels, sep_vals, 's-', color='#A23B72', linewidth=2, markersize=8)
    axes[0, 1].axhline(y=0.5, color='red', linestyle='--', alpha=0.5, label='Threshold=0.5')
    axes[0, 1].set_title('Sep (분리도)', fontweight='bold')
    axes[0, 1].set_ylabel('Sep')
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Inside
    axes[0, 2].plot(grid_labels, inside_vals, '^-', color='#F18F01', linewidth=2, markersize=8)
    axes[0, 2].set_title('Inside (내부성)', fontweight='bold')
    axes[0, 2].set_ylabel('Inside')
    axes[0, 2].grid(True, alpha=0.3)

    # Persist
    axes[1, 0].plot(grid_labels, persist_vals, 'd-', color='#06A77D', linewidth=2, markersize=8)
    axes[1, 0].set_title('Persist (지속성)', fontweight='bold')
    axes[1, 0].set_ylabel('Persist')
    axes[1, 0].grid(True, alpha=0.3)

    # Energy
    axes[1, 1].plot(grid_labels, energy_vals, 'p-', color='#D62828', linewidth=2, markersize=8)
    axes[1, 1].set_title('Energy (전체 에너지)', fontweight='bold')
    axes[1, 1].set_ylabel('Energy')
    axes[1, 1].grid(True, alpha=0.3)

    # Time
    axes[1, 2].bar(grid_labels, time_vals, color='#1B998B', alpha=0.7, edgecolor='black')
    axes[1, 2].set_title('실행 시간', fontweight='bold')
    axes[1, 2].set_ylabel('Time (s)')
    axes[1, 2].grid(True, alpha=0.3, axis='y')

    plt.tight_layout()
    plt.savefig('experiments/results/cohesion_scale_analysis_gpu.png', dpi=150, bbox_inches='tight')
    plt.show()
    
    print("\n✓ 그래프 저장: experiments/results/cohesion_scale_analysis_gpu.png")
else:
    print("그래프를 그리기 위해 2개 이상의 결과가 필요합니다.")

# %% [markdown]
# ## 셀 9️⃣: 결과 다운로드

# %%
from google.colab import files

print("Colab에서 로컬으로 파일을 다운로드합니다...\n")

# JSON 결과 다운로드
try:
    files.download(output_file)
    print(f"✓ {output_file} 다운로드")
except FileNotFoundError:
    print(f"✗ {output_file} 없음")

# 그래프 다운로드
try:
    files.download('experiments/results/cohesion_scale_analysis_gpu.png')
    print(f"✓ cohesion_scale_analysis_gpu.png 다운로드")
except FileNotFoundError:
    print(f"✗ cohesion_scale_analysis_gpu.png 없음")

print("\n✓ 모든 파일 준비 완료")

# %% [markdown]
# ## 셀 🔟: 최종 요약 및 성능 비교

# %%
from datetime import datetime

print("\n" + "="*130)
print("Colab 실험 완료 (GPU 가속)")
print("="*130)
print(f"시간: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"\n실행 모드: {'GPU (CUDA 가속)' if use_gpu else 'CPU'}")
print(f"\n결과 파일:")
print(f"  - {output_file}")
print(f"  - experiments/results/cohesion_scale_analysis_gpu.png")
print(f"\n처리된 격자:")
total_time = 0
for k in sorted(results.keys()):
    t = results[k]['time_sec']
    total_time += t
    print(f"  ✓ {k}: {t:.1f}s")
print(f"\n총 시간: {total_time:.1f}s")
print(f"평균: {total_time/len(results):.1f}s/grid")

# GPU 성능 예상
print(f"\n성능 분석:")
print(f"  CPU 예상: ~{total_time * 2:.1f}s (CPU 대비 2배 느림)")
print(f"  GPU 실제: {total_time:.1f}s")
if total_time > 0:
    speedup = (total_time * 2) / total_time
    print(f"  가속비: {speedup:.1f}x (GPU > CPU)")

print("="*130)
